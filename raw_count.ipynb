# %%
import pandas as pd
csvs = ['721_discuss_RAW.csv', '721_lihkg_RAW.csv',
        'carrie_discuss_RAW.csv', 'carrie_lihkg_RAW.csv',
        'covid_discuss_RAW.csv', 'covid_lihkg_RAW.csv',
        'elab_discuss_RAW.csv', 'elab_lihkg_RAW.csv',
        'election_discuss_RAW.csv', 'election_lihkg_RAW.csv',]

for csv in csvs:
  df = pd.read_csv(csv)
  print(csv, len(df))
# Out:
# 721_discuss_RAW.csv 1439
# 721_lihkg_RAW.csv 1207
# carrie_discuss_RAW.csv 1388
# carrie_lihkg_RAW.csv 2001
# covid_discuss_RAW.csv 1416
# covid_lihkg_RAW.csv 2149
# elab_discuss_RAW.csv 1414
# elab_lihkg_RAW.csv 1992
# election_discuss_RAW.csv 1379
# election_lihkg_RAW.csv 1883

# %%
df = pd.read_csv('721_discuss_RAW.csv')
df
# Out:
#                                                Comments
# 0     https://www.facebook.com/groups/ ... k/2325627...
# 1     原帖由 Reporterdog 於 2019-7-22 01:39 AM 發表\nhttps...
# 2                                                     .
# 3     點解要用水射人，用滅火器射人\n\n[ 本帖最後由 一人少一句 於 2019-7-22 03...
# 4                                     15分15秒開始，有人射水及滅火器
# ...                                                 ...
# 1434  原帖由 vanga 於 2020-7-21 12:10 PM 發表\n林卓廷不是元朗人 , ...
# 1435  原帖由 來自M78星雲的神 於 2020-7-21 12:37 PM 發表\n\n\n黑暴真...
# 1436                                 仆街毒果看圖作文，斬頭斬尾淨係講中間
# 1437  真係好迷，曱甴今日又打左次飛機，已經成為歷史，乜9都係歷史，咁鍾意歷史教育局快啲取消通識開番中史啦
# 1438  原帖由 vanga 於 2020-7-21 12:10 PM 發表\n林卓廷不是元朗人 , ...
#
# [1439 rows x 1 columns]

# %%
### COUNT CLEANED ###
import pandas as pd
csvs = ['721_discuss_CLEANED.csv', '721_lihkg_CLEANED.csv',
#        'carrie_discuss_RAW.csv', 'carrie_lihkg_RAW.csv',
        'covid_discuss_CLEANED.csv', 'covid_lihkg_CLEANED.csv',
#        'elab_discuss_RAW.csv', 'elab_lihkg_RAW.csv',
        'election_discuss_CLEANED.csv', 'election_lihkg_CLEANED.csv',]

for csv in csvs:
  df = pd.read_csv(csv)
  print(csv, len(df))
# Out:
# 721_discuss_CLEANED.csv 1413
# 721_lihkg_CLEANED.csv 1115
# covid_discuss_CLEANED.csv 1393
# covid_lihkg_CLEANED.csv 2030
# election_discuss_CLEANED.csv 1353
# election_lihkg_CLEANED.csv 1766
